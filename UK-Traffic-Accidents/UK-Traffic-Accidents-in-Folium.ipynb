# %%
import pandas
import matplotlib.pyplot
from kaggle.api.kaggle_api_extended import KaggleApi
import folium


api = KaggleApi()
api.authenticate()

# %%
# list the files available from the Kaggle data set
accident_data_path = 'bluehorseshoe/uk-2016-road-safety-data'
accident_data_files = api.dataset_list_files(accident_data_path).files
print(accident_data_files)
# Out:
# [Veh.csv, MakeModel2016.csv, Cas.csv, Road-Accident-Safety-Data-Guide.xls, dftRoadSafety_Accidents_2016.csv]

# %%
# make a Pandas dataframe of traffic data file
api.dataset_download_file(accident_data_path, "dftRoadSafety_Accidents_2016.csv")
traffic_data_filepath = "./dftRoadSafety_Accidents_2016.csv.zip"
traffic_data = pandas.read_csv(traffic_data_filepath)

# remove any rows missing coordinates
traffic_data = traffic_data.dropna(subset=['Longitude', 'Latitude'])

traffic_data.head()
# Out:
# C:\Users\Brian\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  2016010000005               519310.0                188730.0  -0.279323
# 1  2016010000006               551920.0                174560.0   0.184928
# 2  2016010000008               505930.0                183850.0  -0.473837
# 3  2016010000016               527770.0                168930.0  -0.164442
# 4  2016010000018               510740.0                177230.0  -0.406580
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.584754             1                  3                   2
# 1  51.449595             1                  3                   1
# 2  51.543563             1                  3                   1
# ...

# %%
# create a map with a pointer for each accident location
locations = traffic_data[['Latitude', 'Longitude']]
locationlist = locations.values.tolist()

traffic_map = folium.Map(location=[51.5074, 0.1278], zoom_start=10)

# test mapping the first 100 locations
for location in locationlist[0:99]:
    folium.Marker(location).add_to(traffic_map)

traffic_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
